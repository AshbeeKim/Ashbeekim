# %% [markdown]
# <a href="https://colab.research.google.com/github/AshbeeKim/Summarizaion_and_Minutes/blob/main/Basic_WebScraping_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Searching</h1>
#
#
# ```
# from bs4 import BeautifulSoup as BS
#
# # dynamic WebScarping
# if 'google.colab' in sys.modules:
#   !apt-get update
#   !apt install chromium-chromedriver
#   !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# if 'selenium' not in sys.modules:
#   !pip install selenium
# import selenium
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support.ui import WebDriverWait
# from selenium.webdriver.common.keys import Keys
#
# # dynamic WebScraping init
# c_options = webdriver.ChromeOptions ()
# c_options.add_argument ('--headless')
# c_options.add_argument ('--no-sandbox')
# c_options.add_argument ('--disable-dev-shm-usage')
# wd = webdriver.Chrome('chromedriver', options=c_options)
# # wd = webdriver.Chrome('chromedriver', chrome_options=c_options)
#
# url = "https://numpy.org/doc/stable/"
# wd.get(url)
#
# keyword = input("Q : ")
#
# search_id = wd.find_element(By.ID, "search-input")
# search_id.send_keys(keyword)
# search_id.send_keys(Keys.RETURN)
#
# wd.implicitly_wait(random.randint(3,5))
#
# srclst = wd.find_element(By.XPATH, '//*[@id="search-results"]/ul')
#
# # from
# soup = BS(wd.page_source, "lxml")
# soup.get_text(separator='\n', strip='\n\t')
#
# # # tried 3
# # srched_img = wd.get_screenshot_as_png()
# ```
#
# -----
#
# 출력형태
#
#
#
# ```
# Search — NumPy v1.21 Manual
# User Guide
# API reference
# Development
# GitHub
# Twitter
# Search
# $('#fallback').hide();
# Please activate JavaScript to enable the search
#     functionality.
# Searching for multiple words only shows matches that contain
#     all words.
# Search Results
# Search finished, found 1369 page(s) matching the search query.
# numpy.ma
# (Python module, in The
# numpy.ma
# module)
# numpy.distutils.exec_command
# (Python module, in numpy.distutils.exec_command)
# numpy.lib.format
# (Python module, in numpy.lib.format)
# numpy.lib.scimath
# (Python module, in Mathematical functions with automatic domain (
# numpy.emath
# ))
# numpy.matlib
# (Python module, in Matrix library (
# numpy.matlib
# ))
# Constants of the
# numpy.ma
# module
# NumPy 1.10.0 Release Notes
# NumPy 1.11.0 Release Notes
# NumPy 1.12.0 Release Notes
# NumPy 1.14.0 Release Notes
# NumPy 1.15.0 Release Notes
# NumPy 1.18.0 Release Notes
# NumPy 1.6.0 Release Notes
# numpy.ma.all
# numpy.ma.allclose
# numpy.ma.allequal
# numpy.ma.anom
# numpy.ma.anomalies
# numpy.ma.any
# numpy.ma.append
# numpy.ma.apply_along_axis
# numpy.ma.apply_over_axes
# numpy.ma.arange
# numpy.ma.argmax
# numpy.ma.argmin
# numpy.ma.argsort
# numpy.ma.around
# numpy.ma.array
# numpy.ma.asanyarray
# numpy.ma.asarray
# numpy.ma.atleast_1d
# numpy.ma.atleast_2d
# numpy.ma.atleast_3d
# numpy.ma.average
# numpy.ma.choose
# numpy.ma.clip
# numpy.ma.clump_masked
# numpy.ma.clump_unmasked
# numpy.ma.column_stack
# numpy.ma.common_fill_value
# numpy.ma.compress_cols
# numpy.ma.compress_rowcols
# numpy.ma.compress_rows
# numpy.ma.compressed
# numpy.ma.concatenate
# numpy.ma.conjugate
# numpy.ma.copy
# numpy.ma.corrcoef
# numpy.ma.count
# numpy.ma.count_masked
# numpy.ma.cov
# numpy.ma.cumprod
# numpy.ma.cumsum
# numpy.ma.default_fill_value
# numpy.ma.diag
# numpy.ma.dot
# numpy.ma.dstack
# numpy.ma.ediff1d
# numpy.ma.empty
# numpy.ma.empty_like
# numpy.ma.expand_dims
# numpy.ma.filled
# numpy.ma.fix_invalid
# numpy.ma.flatnotmasked_contiguous
# numpy.ma.flatnotmasked_edges
# numpy.ma.frombuffer
# numpy.ma.fromfunction
# numpy.ma.getdata
# numpy.ma.getmask
# numpy.ma.getmaskarray
# numpy.ma.harden_mask
# numpy.ma.hsplit
# numpy.ma.hstack
# numpy.ma.identity
# numpy.ma.indices
# numpy.ma.inner
# numpy.ma.innerproduct
# numpy.ma.is_mask
# numpy.ma.is_masked
# numpy.ma.isarray
# numpy.ma.isMA
# numpy.ma.isMaskedArray
# numpy.ma.make_mask
# numpy.ma.make_mask_descr
# numpy.ma.make_mask_none
# numpy.ma.mask_cols
# numpy.ma.mask_or
# numpy.ma.mask_rowcols
# numpy.ma.mask_rows
# numpy.ma.masked_all
# numpy.ma.masked_all_like
# numpy.ma.masked_array
# numpy.ma.masked_array.all
# numpy.ma.masked_array.anom
# numpy.ma.masked_array.any
# numpy.ma.masked_array.argmax
# numpy.ma.masked_array.argmin
# numpy.ma.masked_array.argpartition
# numpy.ma.masked_array.argsort
# numpy.ma.masked_array.astype
# numpy.ma.masked_array.base
# numpy.ma.masked_array.baseclass
# numpy.ma.masked_array.byteswap
# numpy.ma.masked_array.choose
# numpy.ma.masked_array.clip
# numpy.ma.masked_array.compress
# numpy.ma.masked_array.compressed
# numpy.ma.masked_array.conj
# numpy.ma.masked_array.conjugate
# numpy.ma.masked_array.copy
# numpy.ma.masked_array.count
# numpy.ma.masked_array.ctypes
# numpy.ma.masked_array.cumprod
# numpy.ma.masked_array.cumsum
# numpy.ma.masked_array.data
# numpy.ma.masked_array.diagonal
# numpy.ma.masked_array.dot
# numpy.ma.masked_array.dtype
# numpy.ma.masked_array.dump
# numpy.ma.masked_array.dumps
# numpy.ma.masked_array.fill
# numpy.ma.masked_array.fill_value
# numpy.ma.masked_array.filled
# numpy.ma.masked_array.flags
# numpy.ma.masked_array.flat
# numpy.ma.masked_array.flatten
# numpy.ma.masked_array.get_fill_value
# numpy.ma.masked_array.get_imag
# numpy.ma.masked_array.get_real
# numpy.ma.masked_array.getfield
# numpy.ma.masked_array.harden_mask
# numpy.ma.masked_array.hardmask
# numpy.ma.masked_array.ids
# numpy.ma.masked_array.imag
# numpy.ma.masked_array.iscontiguous
# numpy.ma.masked_array.item
# numpy.ma.masked_array.itemset
# numpy.ma.masked_array.itemsize
# numpy.ma.masked_array.mask
# numpy.ma.masked_array.max
# numpy.ma.masked_array.mean
# numpy.ma.masked_array.min
# numpy.ma.masked_array.mini
# numpy.ma.masked_array.nbytes
# numpy.ma.masked_array.ndim
# numpy.ma.masked_array.newbyteorder
# numpy.ma.masked_array.nonzero
# numpy.ma.masked_array.partition
# numpy.ma.masked_array.prod
# numpy.ma.masked_array.product
# numpy.ma.masked_array.ptp
# numpy.ma.masked_array.put
# numpy.ma.masked_array.ravel
# numpy.ma.masked_array.real
# numpy.ma.masked_array.recordmask
# numpy.ma.masked_array.repeat
# numpy.ma.masked_array.reshape
# numpy.ma.masked_array.resize
# numpy.ma.masked_array.round
# numpy.ma.masked_array.searchsorted
# numpy.ma.masked_array.set_fill_value
# numpy.ma.masked_array.setfield
# numpy.ma.masked_array.setflags
# numpy.ma.masked_array.shape
# numpy.ma.masked_array.sharedmask
# numpy.ma.masked_array.shrink_mask
# numpy.ma.masked_array.size
# numpy.ma.masked_array.soften_mask
# numpy.ma.masked_array.sort
# numpy.ma.masked_array.squeeze
# numpy.ma.masked_array.std
# numpy.ma.masked_array.strides
# numpy.ma.masked_array.sum
# numpy.ma.masked_array.swapaxes
# numpy.ma.masked_array.T
# numpy.ma.masked_array.take
# numpy.ma.masked_array.tobytes
# numpy.ma.masked_array.tofile
# numpy.ma.masked_array.toflex
# numpy.ma.masked_array.tolist
# numpy.ma.masked_array.torecords
# numpy.ma.masked_array.tostring
# numpy.ma.masked_array.trace
# numpy.ma.masked_array.transpose
# numpy.ma.masked_array.unshare_mask
# numpy.ma.masked_array.var
# numpy.ma.masked_array.view
# numpy.ma.masked_equal
# numpy.ma.masked_greater
# numpy.ma.masked_greater_equal
# numpy.ma.masked_inside
# numpy.ma.masked_invalid
# numpy.ma.masked_less
# numpy.ma.masked_less_equal
# numpy.ma.masked_not_equal
# numpy.ma.masked_object
# numpy.ma.masked_outside
# numpy.ma.masked_values
# numpy.ma.masked_where
# numpy.ma.MaskedArray.__abs__
# numpy.ma.MaskedArray.__add__
# numpy.ma.MaskedArray.__and__
# numpy.ma.MaskedArray.__array__
# numpy.ma.MaskedArray.__array_priority__
# numpy.ma.MaskedArray.__array_wrap__
# numpy.ma.MaskedArray.__bool__
# numpy.ma.MaskedArray.__contains__
# numpy.ma.MaskedArray.__copy__
# numpy.ma.MaskedArray.__deepcopy__
# numpy.ma.MaskedArray.__delitem__
# numpy.ma.MaskedArray.__div__
# numpy.ma.MaskedArray.__divmod__
# numpy.ma.MaskedArray.__eq__
# numpy.ma.MaskedArray.__float__
# numpy.ma.MaskedArray.__floordiv__
# numpy.ma.MaskedArray.__ge__
# numpy.ma.MaskedArray.__getitem__
# numpy.ma.MaskedArray.__getstate__
# numpy.ma.MaskedArray.__gt__
# numpy.ma.MaskedArray.__iadd__
# numpy.ma.MaskedArray.__iand__
# numpy.ma.MaskedArray.__idiv__
# numpy.ma.MaskedArray.__ifloordiv__
# numpy.ma.MaskedArray.__ilshift__
# numpy.ma.MaskedArray.__imod__
# numpy.ma.MaskedArray.__imul__
# numpy.ma.MaskedArray.__int__
# numpy.ma.MaskedArray.__ior__
# numpy.ma.MaskedArray.__ipow__
# numpy.ma.MaskedArray.__irshift__
# numpy.ma.MaskedArray.__isub__
# numpy.ma.MaskedArray.__itruediv__
# numpy.ma.MaskedArray.__ixor__
# numpy.ma.MaskedArray.__le__
# numpy.ma.MaskedArray.__len__
# numpy.ma.MaskedArray.__lshift__
# numpy.ma.MaskedArray.__lt__
# numpy.ma.MaskedArray.__mod__
# numpy.ma.MaskedArray.__mul__
# numpy.ma.MaskedArray.__ne__
# numpy.ma.MaskedArray.__new__
# numpy.ma.MaskedArray.__or__
# numpy.ma.MaskedArray.__pow__
# numpy.ma.MaskedArray.__radd__
# numpy.ma.MaskedArray.__rand__
# numpy.ma.MaskedArray.__rdivmod__
# numpy.ma.MaskedArray.__reduce__
# numpy.ma.MaskedArray.__repr__
# numpy.ma.MaskedArray.__rfloordiv__
# numpy.ma.MaskedArray.__rlshift__
# numpy.ma.MaskedArray.__rmod__
# numpy.ma.MaskedArray.__rmul__
# numpy.ma.MaskedArray.__ror__
# numpy.ma.MaskedArray.__rpow__
# numpy.ma.MaskedArray.__rrshift__
# numpy.ma.MaskedArray.__rshift__
# numpy.ma.MaskedArray.__rsub__
# numpy.ma.MaskedArray.__rtruediv__
# numpy.ma.MaskedArray.__rxor__
# numpy.ma.MaskedArray.__setitem__
# numpy.ma.MaskedArray.__setmask__
# numpy.ma.MaskedArray.__setstate__
# numpy.ma.MaskedArray.__str__
# numpy.ma.MaskedArray.__sub__
# numpy.ma.MaskedArray.__truediv__
# numpy.ma.MaskedArray.__xor__
# numpy.ma.MaskedArray.all
# numpy.ma.MaskedArray.anom
# numpy.ma.MaskedArray.any
# numpy.ma.MaskedArray.argmax
# numpy.ma.MaskedArray.argmin
# numpy.ma.MaskedArray.argsort
# numpy.ma.MaskedArray.astype
# numpy.ma.MaskedArray.base
# numpy.ma.MaskedArray.byteswap
# numpy.ma.MaskedArray.choose
# numpy.ma.MaskedArray.clip
# numpy.ma.MaskedArray.compress
# numpy.ma.MaskedArray.compressed
# numpy.ma.MaskedArray.conj
# numpy.ma.MaskedArray.conjugate
# numpy.ma.MaskedArray.copy
# numpy.ma.MaskedArray.count
# numpy.ma.MaskedArray.ctypes
# numpy.ma.MaskedArray.cumprod
# numpy.ma.MaskedArray.cumsum
# numpy.ma.MaskedArray.diagonal
# numpy.ma.MaskedArray.dtype
# numpy.ma.MaskedArray.dump
# numpy.ma.MaskedArray.dumps
# numpy.ma.MaskedArray.fill
# numpy.ma.MaskedArray.filled
# numpy.ma.MaskedArray.flags
# numpy.ma.MaskedArray.flat
# numpy.ma.MaskedArray.flatten
# numpy.ma.MaskedArray.get_fill_value
# numpy.ma.MaskedArray.harden_mask
# numpy.ma.MaskedArray.ids
# numpy.ma.MaskedArray.imag
# numpy.ma.MaskedArray.iscontiguous
# numpy.ma.MaskedArray.item
# numpy.ma.MaskedArray.itemsize
# numpy.ma.MaskedArray.max
# numpy.ma.MaskedArray.mean
# numpy.ma.MaskedArray.min
# numpy.ma.MaskedArray.nbytes
# numpy.ma.MaskedArray.ndim
# numpy.ma.MaskedArray.nonzero
# numpy.ma.MaskedArray.prod
# numpy.ma.MaskedArray.product
# numpy.ma.MaskedArray.ptp
# numpy.ma.MaskedArray.put
# numpy.ma.MaskedArray.ravel
# numpy.ma.MaskedArray.real
# numpy.ma.MaskedArray.repeat
# numpy.ma.MaskedArray.reshape
# numpy.ma.MaskedArray.resize
# numpy.ma.MaskedArray.round
# numpy.ma.MaskedArray.searchsorted
# numpy.ma.MaskedArray.set_fill_value
# numpy.ma.MaskedArray.shape
# numpy.ma.MaskedArray.shrink_mask
# numpy.ma.MaskedArray.size
# numpy.ma.MaskedArray.soften_mask
# numpy.ma.MaskedArray.sort
# numpy.ma.MaskedArray.squeeze
# numpy.ma.MaskedArray.std
# numpy.ma.MaskedArray.strides
# numpy.ma.MaskedArray.sum
# numpy.ma.MaskedArray.swapaxes
# numpy.ma.MaskedArray.T
# numpy.ma.MaskedArray.take
# numpy.ma.MaskedArray.tobytes
# numpy.ma.MaskedArray.tofile
# numpy.ma.MaskedArray.toflex
# numpy.ma.MaskedArray.tolist
# numpy.ma.MaskedArray.torecords
# numpy.ma.MaskedArray.tostring
# numpy.ma.MaskedArray.trace
# numpy.ma.MaskedArray.transpose
# numpy.ma.MaskedArray.unshare_mask
# numpy.ma.MaskedArray.var
# numpy.ma.MaskedArray.view
# numpy.ma.MaskType
# numpy.ma.MaskType.all
# numpy.ma.MaskType.any
# numpy.ma.MaskType.argmax
# numpy.ma.MaskType.argmin
# numpy.ma.MaskType.argsort
# numpy.ma.MaskType.astype
# numpy.ma.MaskType.base
# numpy.ma.MaskType.byteswap
# numpy.ma.MaskType.choose
# numpy.ma.MaskType.clip
# numpy.ma.MaskType.compress
# numpy.ma.MaskType.conj
# numpy.ma.MaskType.conjugate
# numpy.ma.MaskType.copy
# numpy.ma.MaskType.cumprod
# numpy.ma.MaskType.cumsum
# numpy.ma.MaskType.data
# numpy.ma.MaskType.diagonal
# numpy.ma.MaskType.dtype
# numpy.ma.MaskType.dump
# numpy.ma.MaskType.dumps
# numpy.ma.MaskType.fill
# numpy.ma.MaskType.flags
# numpy.ma.MaskType.flat
# numpy.ma.MaskType.flatten
# numpy.ma.MaskType.getfield
# numpy.ma.MaskType.imag
# numpy.ma.MaskType.item
# numpy.ma.MaskType.itemset
# numpy.ma.MaskType.itemsize
# numpy.ma.MaskType.max
# numpy.ma.MaskType.mean
# numpy.ma.MaskType.min
# numpy.ma.MaskType.nbytes
# numpy.ma.MaskType.ndim
# numpy.ma.MaskType.newbyteorder
# numpy.ma.MaskType.nonzero
# numpy.ma.MaskType.prod
# numpy.ma.MaskType.ptp
# numpy.ma.MaskType.put
# numpy.ma.MaskType.ravel
# numpy.ma.MaskType.real
# numpy.ma.MaskType.repeat
# numpy.ma.MaskType.reshape
# numpy.ma.MaskType.resize
# numpy.ma.MaskType.round
# numpy.ma.MaskType.searchsorted
# numpy.ma.MaskType.setfield
# numpy.ma.MaskType.setflags
# numpy.ma.MaskType.shape
# numpy.ma.MaskType.size
# numpy.ma.MaskType.sort
# numpy.ma.MaskType.squeeze
# numpy.ma.MaskType.std
# numpy.ma.MaskType.strides
# numpy.ma.MaskType.sum
# numpy.ma.MaskType.swapaxes
# numpy.ma.MaskType.T
# numpy.ma.MaskType.take
# numpy.ma.MaskType.tobytes
# numpy.ma.MaskType.tofile
# numpy.ma.MaskType.tolist
# numpy.ma.MaskType.tostring
# numpy.ma.MaskType.trace
# numpy.ma.MaskType.transpose
# numpy.ma.MaskType.var
# numpy.ma.MaskType.view
# numpy.ma.max
# numpy.ma.maximum_fill_value
# numpy.ma.mean
# numpy.ma.median
# numpy.ma.min
# numpy.ma.minimum_fill_value
# numpy.ma.mr_
# numpy.ma.nonzero
# numpy.ma.notmasked_contiguous
# numpy.ma.notmasked_edges
# numpy.ma.ones
# numpy.ma.outer
# numpy.ma.outerproduct
# numpy.ma.polyfit
# numpy.ma.power
# numpy.ma.prod
# numpy.ma.ptp
# numpy.ma.ravel
# numpy.ma.reshape
# numpy.ma.resize
# numpy.ma.round
# numpy.ma.row_stack
# numpy.ma.set_fill_value
# numpy.ma.shape
# numpy.ma.size
# numpy.ma.soften_mask
# numpy.ma.sort
# numpy.ma.squeeze
# numpy.ma.stack
# numpy.ma.std
# numpy.ma.sum
# numpy.ma.swapaxes
# numpy.ma.trace
# numpy.ma.transpose
# numpy.ma.vander
# numpy.ma.var
# numpy.ma.vstack
# numpy.ma.where
# numpy.ma.zeros
# Standard array subclasses
# The
# numpy.ma
# module
# castfunc.fromarr
# (C function parameter, in Beyond the Basics)
# NPY_MASK
# (C enumerator, in Data Type API)
# NPY_MAX_BUFSIZE
# (C macro, in Array API)
# NPY_MAXARGS
# (C macro, in Array API)
# NPY_MAXDIMS
# (C macro, in Array API)
# NpyIter_MultiNew.NPY_ITER_ARRAYMASK
# (C macro, in Array Iterator API)
# NpyIter_MultiNew.NPY_ITER_WRITEMASKED
# (C macro, in Array Iterator API)
# numpy.amax
# (Python function, in numpy.amax)
# numpy.argmax
# (Python function, in numpy.argmax)
# numpy.asmatrix
# (Python function, in numpy.asmatrix)
# numpy.blackman
# (Python function, in numpy.blackman)
# numpy.bmat
# (Python function, in numpy.bmat)
# numpy.busdaycalendar.weekmask
# (Python attribute, in numpy.busdaycalendar.weekmask)
# numpy.char.chararray.argmax
# (Python method, in numpy.char.chararray.argmax)
# numpy.char.chararray.imag
# (Python attribute, in numpy.char.chararray.imag)
# numpy.char.chararray.isdecimal
# (Python method, in numpy.char.chararray.isdecimal)
# numpy.char.chararray.max
# (Python method, in numpy.char.chararray.max)
# numpy.char.isdecimal
# (Python function, in numpy.char.isdecimal)
# numpy.chararray.argmax
# (Python method, in numpy.chararray.argmax)
# numpy.chararray.imag
# (Python attribute, in numpy.chararray.imag)
# numpy.chararray.isdecimal
# (Python method, in numpy.chararray.isdecimal)
# numpy.chararray.max
# (Python method, in numpy.chararray.max)
# numpy.core.records.fromarrays
# (Python function, in numpy.core.records.fromarrays)
# numpy.distutils.ccompiler.simple_version_match
# (Python function, in numpy.distutils.ccompiler.simple_version_match)
# numpy.distutils.ccompiler_opt.CCompilerOpt.cc_normalize_flags
# (Python method, in numpy.distutils.ccompiler_opt.CCompilerOpt.cc_normalize_flags)
# numpy.distutils.exec_command.exec_command
# (Python function, in numpy.distutils.exec_command.exec_command)
# numpy.distutils.misc_util.Configuration.make_config_py
# (Python method, in Packaging (
# numpy.distutils
# ))
# numpy.distutils.misc_util.Configuration.make_svn_version_py
# (Python method, in Packaging (
# numpy.distutils
# ))
# numpy.distutils.misc_util.get_mathlibs
# (Python function, in distutils.misc_util)
# numpy.euler_gamma
# (Python data, in Constants)
# numpy.f2py.run_main
# (Python function, in Using F2PY)
# numpy.fmax
# (Python data, in numpy.fmax)
# numpy.format_float_positional
# (Python function, in numpy.format_float_positional)
# numpy.format_float_scientific
# (Python function, in numpy.format_float_scientific)
# numpy.format_parser
# (Python class, in numpy.format_parser)
# numpy.generic.imag
# (Python attribute, in numpy.generic.imag)
# numpy.iinfo.max
# (Python property, in numpy.iinfo.max)
# numpy.imag
# (Python function, in numpy.imag)
# numpy.lib.format.magic
# (Python function, in numpy.lib.format.magic)
# numpy.lib.format.open_memmap
# (Python function, in numpy.lib.format.open_memmap)
# numpy.lib.format.read_magic
# (Python function, in numpy.lib.format.read_magic)
# numpy.linalg.matrix_power
# (Python function, in numpy.linalg.matrix_power)
# numpy.linalg.matrix_rank
# (Python function, in numpy.linalg.matrix_rank)
# numpy.ma.anomalies
# (Python data, in numpy.ma.anomalies)
# numpy.ma.argmax
# (Python data, in numpy.ma.argmax)
# numpy.ma.clump_masked
# (Python function, in numpy.ma.clump_masked)
# numpy.ma.clump_unmasked
# (Python function, in numpy.ma.clump_unmasked)
# numpy.ma.count_masked
# (Python function, in numpy.ma.count_masked)
# numpy.ma.flatnotmasked_contiguous
# (Python function, in numpy.ma.flatnotmasked_contiguous)
# numpy.ma.flatnotmasked_edges
# (Python function, in numpy.ma.flatnotmasked_edges)
# numpy.ma.getmask
# (Python function, in numpy.ma.getmask)
# numpy.ma.getmaskarray
# (Python function, in numpy.ma.getmaskarray)
# numpy.ma.harden_mask
# (Python data, in numpy.ma.harden_mask)
# numpy.ma.is_mask
# (Python function, in numpy.ma.is_mask)
# numpy.ma.is_masked
# (Python function, in numpy.ma.is_masked)
# numpy.ma.isMA
# (Python function, in numpy.ma.isMA)
# numpy.ma.isMaskedArray
# (Python function, in numpy.ma.isMaskedArray)
# numpy.ma.make_mask
# (Python function, in numpy.ma.make_mask)
# numpy.ma.make_mask_descr
# (Python function, in numpy.ma.make_mask_descr)
# numpy.ma.make_mask_none
# (Python function, in numpy.ma.make_mask_none)
# numpy.ma.mask_cols
# (Python function, in numpy.ma.mask_cols)
# numpy.ma.mask_or
# (Python function, in numpy.ma.mask_or)
# numpy.ma.mask_rowcols
# (Python function, in numpy.ma.mask_rowcols)
# numpy.ma.mask_rows
# (Python function, in numpy.ma.mask_rows)
# numpy.ma.masked
# (Python data, in Constants of the
# numpy.ma
# module)
# numpy.ma.masked_all
# (Python function, in numpy.ma.masked_all)
# numpy.ma.masked_all_like
# (Python function, in numpy.ma.masked_all_like)
# numpy.ma.masked_array
# (Python attribute, in numpy.ma.masked_array)
# numpy.ma.masked_array.argmax
# (Python method, in numpy.ma.masked_array.argmax)
# numpy.ma.masked_array.get_imag
# (Python method, in numpy.ma.masked_array.get_imag)
# numpy.ma.masked_array.harden_mask
# (Python method, in numpy.ma.masked_array.harden_mask)
# numpy.ma.masked_array.hardmask
# (Python property, in numpy.ma.masked_array.hardmask)
# numpy.ma.masked_array.imag
# (Python property, in numpy.ma.masked_array.imag)
# numpy.ma.masked_array.mask
# (Python property, in numpy.ma.masked_array.mask)
# numpy.ma.masked_array.max
# (Python method, in numpy.ma.masked_array.max)
# numpy.ma.masked_array.recordmask
# (Python property, in numpy.ma.masked_array.recordmask)
# numpy.ma.masked_array.sharedmask
# (Python property, in numpy.ma.masked_array.sharedmask)
# numpy.ma.masked_array.shrink_mask
# (Python method, in numpy.ma.masked_array.shrink_mask)
# numpy.ma.masked_array.soften_mask
# (Python method, in numpy.ma.masked_array.soften_mask)
# numpy.ma.masked_array.unshare_mask
# (Python method, in numpy.ma.masked_array.unshare_mask)
# numpy.ma.masked_equal
# (Python function, in numpy.ma.masked_equal)
# numpy.ma.masked_greater
# (Python function, in numpy.ma.masked_greater)
# numpy.ma.masked_greater_equal
# (Python function, in numpy.ma.masked_greater_equal)
# numpy.ma.masked_inside
# (Python function, in numpy.ma.masked_inside)
# numpy.ma.masked_invalid
# (Python function, in numpy.ma.masked_invalid)
# numpy.ma.masked_less
# (Python function, in numpy.ma.masked_less)
# numpy.ma.masked_less_equal
# (Python function, in numpy.ma.masked_less_equal)
# numpy.ma.masked_not_equal
# (Python function, in numpy.ma.masked_not_equal)
# numpy.ma.masked_object
# (Python function, in numpy.ma.masked_object)
# numpy.ma.masked_outside
# (Python function, in numpy.ma.masked_outside)
# numpy.ma.masked_print_options
# (Python data, in Constants of the
# numpy.ma
# module)
# numpy.ma.masked_values
# (Python function, in numpy.ma.masked_values)
# numpy.ma.masked_where
# (Python function, in numpy.ma.masked_where)
# numpy.ma.MaskedArray
# (Python class, in Constants of the
# numpy.ma
# module)
# numpy.ma.MaskedArray.__setmask__
# (Python method, in numpy.ma.MaskedArray.__setmask__)
# numpy.ma.MaskedArray.argmax
# (Python method, in numpy.ma.MaskedArray.argmax)
# numpy.ma.MaskedArray.harden_mask
# (Python method, in numpy.ma.MaskedArray.harden_mask)
# numpy.ma.MaskedArray.hardmask
# (Python attribute, in Constants of the
# numpy.ma
# module)
# numpy.ma.MaskedArray.imag
# (Python property, in numpy.ma.MaskedArray.imag)
# numpy.ma.MaskedArray.mask
# (Python attribute, in Constants of the
# numpy.ma
# module)
# numpy.ma.MaskedArray.max
# (Python method, in numpy.ma.MaskedArray.max)
# numpy.ma.MaskedArray.recordmask
# (Python attribute, in Constants of the
# numpy.ma
# module)
# numpy.ma.MaskedArray.sharedmask
# (Python attribute, in Constants of the
# numpy.ma
# module)
# numpy.ma.MaskedArray.shrink_mask
# (Python method, in numpy.ma.MaskedArray.shrink_mask)
# numpy.ma.MaskedArray.soften_mask
# (Python method, in numpy.ma.MaskedArray.soften_mask)
# numpy.ma.MaskedArray.unshare_mask
# (Python method, in numpy.ma.MaskedArray.unshare_mask)
# numpy.ma.MaskType
# (Python attribute, in numpy.ma.MaskType)
# numpy.ma.MaskType.argmax
# (Python method, in numpy.ma.MaskType.argmax)
# numpy.ma.MaskType.imag
# (Python attribute, in numpy.ma.MaskType.imag)
# numpy.ma.MaskType.max
# (Python method, in numpy.ma.MaskType.max)
# numpy.ma.max
# (Python function, in numpy.ma.max)
# numpy.ma.maximum_fill_value
# (Python function, in numpy.ma.maximum_fill_value)
# numpy.ma.nomask
# (Python data, in Constants of the
# numpy.ma
# module)
# numpy.ma.notmasked_contiguous
# (Python function, in numpy.ma.notmasked_contiguous)
# numpy.ma.notmasked_edges
# (Python function, in numpy.ma.notmasked_edges)
# numpy.ma.soften_mask
# (Python data, in numpy.ma.soften_mask)
# numpy.MachAr
# (Python class, in numpy.MachAr)
# numpy.mask_indices
# (Python function, in numpy.mask_indices)
# numpy.mat
# (Python function, in numpy.mat)
# numpy.matlib.repmat
# (Python function, in numpy.matlib.repmat)
# numpy.matmul
# (Python data, in numpy.matmul)
# numpy.matrix
# (Python class, in numpy.matrix)
# numpy.matrix.argmax
# (Python method, in numpy.matrix.argmax)
# numpy.matrix.imag
# (Python attribute, in numpy.matrix.imag)
# numpy.matrix.max
# (Python method, in numpy.matrix.max)
# numpy.maximum
# (Python data, in numpy.maximum)
# numpy.maximum_sctype
# (Python function, in numpy.maximum_sctype)
# numpy.may_share_memory
# (Python function, in numpy.may_share_memory)
# numpy.memmap
# (Python class, in numpy.memmap)
# numpy.memmap.argmax
# (Python method, in numpy.memmap.argmax)
# numpy.memmap.imag
# (Python attribute, in numpy.memmap.imag)
# numpy.memmap.max
# (Python method, in numpy.memmap.max)
# numpy.nanargmax
# (Python function, in numpy.nanargmax)
# numpy.nanmax
# (Python function, in numpy.nanmax)
# numpy.ndarray.__matmul__
# (Python method, in numpy.ndarray.__matmul__)
# numpy.ndarray.argmax
# (Python method, in numpy.ndarray.argmax)
# numpy.ndarray.imag
# (Python attribute, in numpy.ndarray.imag)
# numpy.ndarray.max
# (Python method, in numpy.ndarray.max)
# numpy.polynomial.chebyshev.chebdomain
# (Python data, in numpy.polynomial.chebyshev.chebdomain)
# numpy.polynomial.chebyshev.Chebyshev.domain
# (Python attribute, in numpy.polynomial.chebyshev.Chebyshev.domain)
# numpy.polynomial.chebyshev.Chebyshev.has_samedomain
# (Python method, in numpy.polynomial.chebyshev.Chebyshev.has_samedomain)
# numpy.polynomial.chebyshev.Chebyshev.mapparms
# (Python method, in numpy.polynomial.chebyshev.Chebyshev.mapparms)
# numpy.polynomial.chebyshev.Chebyshev.maxpower
# (Python attribute, in numpy.polynomial.chebyshev.Chebyshev.maxpower)
# numpy.polynomial.hermite.hermadd
# (Python function, in numpy.polynomial.hermite.hermadd)
# numpy.polynomial.hermite.hermdomain
# (Python data, in numpy.polynomial.hermite.hermdomain)
# numpy.polynomial.hermite.Hermite.domain
# (Python attribute, in numpy.polynomial.hermite.Hermite.domain)
# numpy.polynomial.hermite.Hermite.has_samedomain
# (Python method, in numpy.polynomial.hermite.Hermite.has_samedomain)
# numpy.polynomial.hermite.Hermite.mapparms
# (Python method, in numpy.polynomial.hermite.Hermite.mapparms)
# numpy.polynomial.hermite.Hermite.maxpower
# (Python attribute, in numpy.polynomial.hermite.Hermite.maxpower)
# numpy.polynomial.hermite_e.hermedomain
# (Python data, in numpy.polynomial.hermite_e.hermedomain)
# numpy.polynomial.hermite_e.HermiteE.domain
# (Python attribute, in numpy.polynomial.hermite_e.HermiteE.domain)
# numpy.polynomial.hermite_e.HermiteE.has_samedomain
# (Python method, in numpy.polynomial.hermite_e.HermiteE.has_samedomain)
# numpy.polynomial.hermite_e.HermiteE.mapparms
# (Python method, in numpy.polynomial.hermite_e.HermiteE.mapparms)
# numpy.polynomial.hermite_e.HermiteE.maxpower
# (Python attribute, in numpy.polynomial.hermite_e.HermiteE.maxpower)
# numpy.polynomial.laguerre.lagdomain
# (Python data, in numpy.polynomial.laguerre.lagdomain)
# numpy.polynomial.laguerre.Laguerre.domain
# (Python attribute, in numpy.polynomial.laguerre.Laguerre.domain)
# numpy.polynomial.laguerre.Laguerre.has_samedomain
# (Python method, in numpy.polynomial.laguerre.Laguerre.has_samedomain)
# numpy.polynomial.laguerre.Laguerre.mapparms
# (Python method, in numpy.polynomial.laguerre.Laguerre.mapparms)
# numpy.polynomial.laguerre.Laguerre.maxpower
# (Python attribute, in numpy.polynomial.laguerre.Laguerre.maxpower)
# numpy.polynomial.legendre.legdomain
# (Python data, in numpy.polynomial.legendre.legdomain)
# numpy.polynomial.legendre.Legendre.domain
# (Python attribute, in numpy.polynomial.legendre.Legendre.domain)
# numpy.polynomial.legendre.Legendre.has_samedomain
# (Python method, in numpy.polynomial.legendre.Legendre.has_samedomain)
# numpy.polynomial.legendre.Legendre.mapparms
# (Python method, in numpy.polynomial.legendre.Legendre.mapparms)
# numpy.polynomial.legendre.Legendre.maxpower
# (Python attribute, in numpy.polynomial.legendre.Legendre.maxpower)
# numpy.polynomial.polynomial.polydomain
# (Python data, in numpy.polynomial.polynomial.polydomain)
# numpy.polynomial.polynomial.Polynomial.domain
# (Python attribute, in numpy.polynomial.polynomial.Polynomial.domain)
# numpy.polynomial.polynomial.Polynomial.has_samedomain
# (Python method, in numpy.polynomial.polynomial.Polynomial.has_samedomain)
# numpy.polynomial.polynomial.Polynomial.mapparms
# (Python method, in numpy.polynomial.polynomial.Polynomial.mapparms)
# numpy.polynomial.polynomial.Polynomial.maxpower
# (Python attribute, in numpy.polynomial.polynomial.Polynomial.maxpower)
# numpy.polynomial.polyutils.getdomain
# (Python function, in numpy.polynomial.polyutils.getdomain)
# numpy.polynomial.polyutils.mapdomain
# (Python function, in numpy.polynomial.polyutils.mapdomain)
# numpy.polynomial.polyutils.mapparms
# (Python function, in numpy.polynomial.polyutils.mapparms)
# numpy.putmask
# (Python function, in numpy.putmask)
# numpy.random.gamma
# (Python function, in numpy.random.gamma)
# numpy.random.Generator.gamma
# (Python method, in numpy.random.Generator.gamma)
# numpy.random.Generator.lognormal
# (Python method, in numpy.random.Generator.lognormal)
# numpy.random.Generator.multivariate_normal
# (Python method, in numpy.random.Generator.multivariate_normal)
# numpy.random.Generator.normal
# (Python method, in numpy.random.Generator.normal)
# numpy.random.Generator.standard_gamma
# (Python method, in numpy.random.Generator.standard_gamma)
# numpy.random.Generator.standard_normal
# (Python method, in numpy.random.Generator.standard_normal)
# numpy.random.lognormal
# (Python function, in numpy.random.lognormal)
# numpy.random.multivariate_normal
# (Python function, in numpy.random.multivariate_normal)
# numpy.random.normal
# (Python function, in numpy.random.normal)
# numpy.random.RandomState.gamma
# (Python method, in numpy.random.RandomState.gamma)
# numpy.random.RandomState.lognormal
# (Python method, in numpy.random.RandomState.lognormal)
# numpy.random.RandomState.multivariate_normal
# (Python method, in numpy.random.RandomState.multivariate_normal)
# numpy.random.RandomState.normal
# (Python method, in numpy.random.RandomState.normal)
# numpy.random.RandomState.standard_gamma
# (Python method, in numpy.random.RandomState.standard_gamma)
# numpy.random.RandomState.standard_normal
# (Python method, in numpy.random.RandomState.standard_normal)
# numpy.random.standard_gamma
# (Python function, in numpy.random.standard_gamma)
# numpy.random.standard_normal
# (Python function, in numpy.random.standard_normal)
# numpy.recarray.argmax
# (Python method, in numpy.recarray.argmax)
# numpy.recarray.imag
# (Python attribute, in numpy.recarray.imag)
# numpy.recarray.max
# (Python method, in numpy.recarray.max)
# numpy.record.argmax
# (Python method, in numpy.record.argmax)
# numpy.record.imag
# (Python attribute, in numpy.record.imag)
# numpy.record.max
# (Python method, in numpy.record.max)
# numpy.remainder
# (Python data, in numpy.remainder)
# numpy.testing.assert_array_max_ulp
# (Python function, in numpy.testing.assert_array_max_ulp)
# PyArray_ArgMax
# (C function, in Array API)
# PyArray_ArrFuncs.argmax
# (C member, in Python Types and C-Structures)
# PyArray_ArrFuncs.fastputmask
# (C member, in Python Types and C-Structures)
# PyArray_CheckFromAny
# (C function, in Array API)
# PyArray_CheckFromAny.max_depth
# (C function parameter, in Array API)
# PyArray_Clip.max
# (C function parameter, in Array API)
# PyArray_ContiguousFromAny
# (C function, in Array API)
# PyArray_ContiguousFromAny.max_depth
# (C function parameter, in Array API)
# PyArray_ContiguousFromObject.max_depth
# (C function parameter, in Array API)
# PyArray_FromAny
# (C function, in Array API)
# PyArray_FROMANY
# (C function, in Array API)
# PyArray_FROMANY.max
# (C function parameter, in Array API)
# PyArray_FromAny.max_depth
# (C function parameter, in Array API)
# PyArray_FromArray
# (C function, in Array API)
# PyArray_FromArrayAttr
# (C function, in Array API)
# PyArray_FromObject.max_depth
# (C function parameter, in Array API)
# PyArray_IntpFromSequence.maxvals
# (C function parameter, in Array API)
# PyArray_malloc
# (C function, in Array API)
# PyArray_MatrixProduct
# (C function, in Array API)
# PyArray_MatrixProduct2
# (C function, in Array API)
# PyArray_Max
# (C function, in Array API)
# PyArray_MAX
# (C macro, in Array API)
# PyArray_PutMask
# (C function, in Array API)
# PyArray_PutMask.mask
# (C function parameter, in Array API)
# PyArray_RemoveSmallest
# (C function, in Array API)
# PyArray_Round.decimals
# (C function parameter, in Array API)
# PyArray_ToFile.format
# (C function parameter, in Array API)
# PyArray_UpdateFlags.flagmask
# (C function parameter, in Array API)
# PyArrayMapIter_Type
# (C member, in Python Types and C-Structures)
# PyUFunc_checkfperr.errmask
# (C function parameter, in UFunc API)
# PyUFunc_GetPyValues.errmask
# (C function parameter, in UFunc API)
# PyUFuncObject.masked_inner_loop_selector
# (C member, in Python Types and C-Structures)
# random_bounded_uint64.mask
# (C function parameter, in C API for random)
# random_bounded_uint64.use_masked
# (C function parameter, in C API for random)
# random_gamma
# (C function, in C API for random)
# random_gamma_f
# (C function, in C API for random)
# random_interval.max
# (C function parameter, in C API for random)
# random_lognormal
# (C function, in C API for random)
# random_lognormal.sigma
# (C function parameter, in C API for random)
# random_multivariate_hypergeometric_marginals
# (C function, in C API for random)
# random_normal
# (C function, in C API for random)
# random_standard_gamma
# (C function, in C API for random)
# random_standard_gamma_f
# (C function, in C API for random)
# random_standard_normal
# (C function, in C API for random)
# random_standard_normal_f
# (C function, in C API for random)
# random_standard_normal_fill
# (C function, in C API for random)
# random_standard_normal_fill_f
# (C function, in C API for random)
# UFUNC_MASK_DIVIDEBYZERO
# (C macro, in UFunc API)
# UFUNC_MASK_INVALID
# (C macro, in UFunc API)
# UFUNC_MASK_OVERFLOW
# (C macro, in UFunc API)
# UFUNC_MASK_UNDERFLOW
# (C macro, in UFunc API)
# Array objects
# Glossary
# Masked arrays
# NumPy 1.10.2 Release Notes
# NumPy 1.10.4 Release Notes
# NumPy 1.11.1 Release Notes
# NumPy 1.11.2 Release Notes
# NumPy 1.12.1 Release Notes
# NumPy 1.13.0 Release Notes
# NumPy 1.14.3 Release Notes
# NumPy 1.14.6 Release Notes
# NumPy 1.20.2 Release Notes
# NumPy 1.7.2 Release Notes
# NumPy 1.9.0 Release Notes
# NumPy 1.9.2 Release Notes
# numpy.angle
# numpy.array_repr
# numpy.average
# numpy.concatenate
# numpy.distutils.exec_command.filepath_from_subprocess_output
# (Python function, in numpy.distutils.exec_command.filepath_from_subprocess_output)
# numpy.distutils.exec_command.find_executable
# (Python function, in numpy.distutils.exec_command.find_executable)
# numpy.distutils.exec_command.forward_bytes_to_stdout
# (Python function, in numpy.distutils.exec_command.forward_bytes_to_stdout)
# numpy.distutils.exec_command.get_pythonexe
# (Python function, in numpy.distutils.exec_command.get_pythonexe)
# numpy.distutils.exec_command.temp_file_name
# (Python function, in numpy.distutils.exec_command.temp_file_name)
# numpy.lib.format.descr_to_dtype
# (Python function, in numpy.lib.format.descr_to_dtype)
# numpy.lib.format.dtype_to_descr
# (Python function, in numpy.lib.format.dtype_to_descr)
# numpy.lib.format.header_data_from_array_1_0
# (Python function, in numpy.lib.format.header_data_from_array_1_0)
# numpy.lib.format.read_array
# (Python function, in numpy.lib.format.read_array)
# numpy.lib.format.read_array_header_1_0
# (Python function, in numpy.lib.format.read_array_header_1_0)
# numpy.lib.format.read_array_header_2_0
# (Python function, in numpy.lib.format.read_array_header_2_0)
# numpy.lib.format.write_array
# (Python function, in numpy.lib.format.write_array)
# numpy.lib.format.write_array_header_1_0
# (Python function, in numpy.lib.format.write_array_header_1_0)
# numpy.lib.format.write_array_header_2_0
# (Python function, in numpy.lib.format.write_array_header_2_0)
# numpy.lib.scimath.arccos
# (Python function, in numpy.lib.scimath.arccos)
# numpy.lib.scimath.arcsin
# (Python function, in numpy.lib.scimath.arcsin)
# numpy.lib.scimath.arctanh
# (Python function, in numpy.lib.scimath.arctanh)
# numpy.lib.scimath.log
# (Python function, in numpy.lib.scimath.log)
# numpy.lib.scimath.log10
# (Python function, in numpy.lib.scimath.log10)
# numpy.lib.scimath.log2
# (Python function, in numpy.lib.scimath.log2)
# numpy.lib.scimath.logn
# (Python function, in numpy.lib.scimath.logn)
# numpy.lib.scimath.power
# (Python function, in numpy.lib.scimath.power)
# numpy.lib.scimath.sqrt
# (Python function, in numpy.lib.scimath.sqrt)
# numpy.ma.all
# (Python data, in numpy.ma.all)
# numpy.ma.allclose
# (Python function, in numpy.ma.allclose)
# numpy.ma.allequal
# (Python function, in numpy.ma.allequal)
# numpy.ma.anom
# (Python data, in numpy.ma.anom)
# numpy.ma.any
# (Python data, in numpy.ma.any)
# numpy.ma.append
# (Python function, in numpy.ma.append)
# numpy.ma.apply_along_axis
# (Python function, in numpy.ma.apply_along_axis)
# numpy.ma.apply_over_axes
# (Python function, in numpy.ma.apply_over_axes)
# numpy.ma.arange
# (Python data, in numpy.ma.arange)
# numpy.ma.argmin
# (Python data, in numpy.ma.argmin)
# numpy.ma.argsort
# (Python function, in numpy.ma.argsort)
# numpy.ma.around
# (Python data, in numpy.ma.around)
# numpy.ma.array
# (Python function, in numpy.ma.array)
# numpy.ma.asanyarray
# (Python function, in numpy.ma.asanyarray)
# numpy.ma.asarray
# (Python function, in numpy.ma.asarray)
# numpy.ma.atleast_1d
# (Python data, in numpy.ma.atleast_1d)
# numpy.ma.atleast_2d
# (Python data, in numpy.ma.atleast_2d)
# numpy.ma.atleast_3d
# (Python data, in numpy.ma.atleast_3d)
# numpy.ma.average
# (Python function, in numpy.ma.average)
# numpy.ma.choose
# (Python function, in numpy.ma.choose)
# numpy.ma.clip
# (Python function, in numpy.ma.clip)
# numpy.ma.column_stack
# (Python data, in numpy.ma.column_stack)
# numpy.ma.common_fill_value
# (Python function, in numpy.ma.common_fill_value)
# numpy.ma.compress_cols
# (Python function, in numpy.ma.compress_cols)
# numpy.ma.compress_rowcols
# (Python function, in numpy.ma.compress_rowcols)
# numpy.ma.compress_rows
# (Python function, in numpy.ma.compress_rows)
# numpy.ma.compressed
# (Python function, in numpy.ma.compressed)
# numpy.ma.concatenate
# (Python function, in numpy.ma.concatenate)
# numpy.ma.conjugate
# (Python data, in numpy.ma.conjugate)
# numpy.ma.copy
# (Python data, in numpy.ma.copy)
# numpy.ma.corrcoef
# (Python function, in numpy.ma.corrcoef)
# numpy.ma.count
# (Python data, in numpy.ma.count)
# numpy.ma.cov
# (Python function, in numpy.ma.cov)
# numpy.ma.cumprod
# (Python data, in numpy.ma.cumprod)
# numpy.ma.cumsum
# (Python data, in numpy.ma.cumsum)
# numpy.ma.default_fill_value
# (Python function, in numpy.ma.default_fill_value)
# numpy.ma.diag
# (Python function, in numpy.ma.diag)
# numpy.ma.dot
# (Python function, in numpy.ma.dot)
# numpy.ma.dstack
# (Python data, in numpy.ma.dstack)
# numpy.ma.ediff1d
# (Python function, in numpy.ma.ediff1d)
# numpy.ma.empty
# (Python data, in numpy.ma.empty)
# numpy.ma.empty_like
# (Python data, in numpy.ma.empty_like)
# numpy.ma.expand_dims
# (Python function, in numpy.ma.expand_dims)
# numpy.ma.filled
# (Python function, in numpy.ma.filled)
# numpy.ma.fix_invalid
# (Python function, in numpy.ma.fix_invalid)
# numpy.ma.frombuffer
# (Python data, in numpy.ma.frombuffer)
# numpy.ma.fromfunction
# (Python data, in numpy.ma.fromfunction)
# numpy.ma.getdata
# (Python function, in numpy.ma.getdata)
# numpy.ma.hsplit
# (Python data, in numpy.ma.hsplit)
# numpy.ma.hstack
# (Python data, in numpy.ma.hstack)
# numpy.ma.identity
# (Python data, in numpy.ma.identity)
# numpy.ma.indices
# (Python function, in numpy.ma.indices)
# numpy.ma.inner
# (Python function, in numpy.ma.inner)
# numpy.ma.innerproduct
# (Python function, in numpy.ma.innerproduct)
# numpy.ma.isarray
# (Python function, in numpy.ma.isarray)
# numpy.ma.masked_array.all
# (Python method, in numpy.ma.masked_array.all)
# numpy.ma.masked_array.anom
# (Python method, in numpy.ma.masked_array.anom)
# numpy.ma.masked_array.any
# (Python method, in numpy.ma.masked_array.any)
# numpy.ma.masked_array.argmin
# (Python method, in numpy.ma.masked_array.argmin)
# numpy.ma.masked_array.argpartition
# (Python method, in numpy.ma.masked_array.argpartition)
# numpy.ma.masked_array.argsort
# (Python method, in numpy.ma.masked_array.argsort)
# numpy.ma.masked_array.astype
# (Python method, in numpy.ma.masked_array.astype)
# numpy.ma.masked_array.base
# (Python attribute, in numpy.ma.masked_array.base)
# numpy.ma.masked_array.baseclass
# (Python property, in numpy.ma.masked_array.baseclass)
# numpy.ma.masked_array.byteswap
# (Python method, in numpy.ma.masked_array.byteswap)
# numpy.ma.masked_array.choose
# (Python method, in numpy.ma.masked_array.choose)
# numpy.ma.masked_array.clip
# (Python method, in numpy.ma.masked_array.clip)
# numpy.ma.masked_array.compress
# (Python method, in numpy.ma.masked_array.compress)
# numpy.ma.masked_array.compressed
# (Python method, in numpy.ma.masked_array.compressed)
# numpy.ma.masked_array.conj
# (Python method, in numpy.ma.masked_array.conj)
# numpy.ma.masked_array.conjugate
# (Python method, in numpy.ma.masked_array.conjugate)
# numpy.ma.masked_array.copy
# (Python method, in numpy.ma.masked_array.copy)
# numpy.ma.masked_array.count
# (Python method, in numpy.ma.masked_array.count)
# numpy.ma.masked_array.ctypes
# (Python attribute, in numpy.ma.masked_array.ctypes)
# numpy.ma.masked_array.cumprod
# (Python method, in numpy.ma.masked_array.cumprod)
# numpy.ma.masked_array.cumsum
# (Python method, in numpy.ma.masked_array.cumsum)
# numpy.ma.masked_array.data
# (Python property, in numpy.ma.masked_array.data)
# numpy.ma.masked_array.diagonal
# (Python method, in numpy.ma.masked_array.diagonal)
# numpy.ma.masked_array.dot
# (Python method, in numpy.ma.masked_array.dot)
# numpy.ma.masked_array.dtype
# (Python property, in numpy.ma.masked_array.dtype)
# numpy.ma.masked_array.dump
# (Python method, in numpy.ma.masked_array.dump)
# numpy.ma.masked_array.dumps
# (Python method, in numpy.ma.masked_array.dumps)
# numpy.ma.masked_array.fill
# (Python method, in numpy.ma.masked_array.fill)
# numpy.ma.masked_array.fill_value
# (Python property, in numpy.ma.masked_array.fill_value)
# numpy.ma.masked_array.filled
# (Python method, in numpy.ma.masked_array.filled)
# numpy.ma.masked_array.flags
# (Python attribute, in numpy.ma.masked_array.flags)
# numpy.ma.masked_array.flat
# (Python property, in numpy.ma.masked_array.flat)
# numpy.ma.masked_array.flatten
# (Python method, in numpy.ma.masked_array.flatten)
# numpy.ma.masked_array.get_fill_value
# (Python method, in numpy.ma.masked_array.get_fill_value)
# numpy.ma.masked_array.get_real
# (Python method, in numpy.ma.masked_array.get_real)
# numpy.ma.masked_array.getfield
# (Python method, in numpy.ma.masked_array.getfield)
# numpy.ma.masked_array.ids
# (Python method, in numpy.ma.masked_array.ids)
# numpy.ma.masked_array.iscontiguous
# (Python method, in numpy.ma.masked_array.iscontiguous)
# numpy.ma.masked_array.item
# (Python method, in numpy.ma.masked_array.item)
# numpy.ma.masked_array.itemset
# (Python method, in numpy.ma.masked_array.itemset)
# numpy.ma.masked_array.itemsize
# (Python attribute, in numpy.ma.masked_array.itemsize)
# numpy.ma.masked_array.mean
# (Python method, in numpy.ma.masked_array.mean)
# numpy.ma.masked_array.min
# (Python method, in numpy.ma.masked_array.min)
# numpy.ma.masked_array.mini
# (Python method, in numpy.ma.masked_array.mini)
# numpy.ma.masked_array.nbytes
# (Python attribute, in numpy.ma.masked_array.nbytes)
# numpy.ma.masked_array.ndim
# (Python attribute, in numpy.ma.masked_array.ndim)
# numpy.ma.masked_array.newbyteorder
# (Python method, in numpy.ma.masked_array.newbyteorder)
# numpy.ma.masked_array.nonzero
# (Python method, in numpy.ma.masked_array.nonzero)
# numpy.ma.masked_array.partition
# (Python method, in numpy.ma.masked_array.partition)
# numpy.ma.masked_array.prod
# (Python method, in numpy.ma.masked_array.prod)
# numpy.ma.masked_array.product
# (Python method, in numpy.ma.masked_array.product)
# numpy.ma.masked_array.ptp
# (Python method, in numpy.ma.masked_array.ptp)
# numpy.ma.masked_array.put
# (Python method, in numpy.ma.masked_array.put)
# numpy.ma.masked_array.ravel
# (Python method, in numpy.ma.masked_array.ravel)
# numpy.ma.masked_array.real
# (Python property, in numpy.ma.masked_array.real)
# numpy.ma.masked_array.repeat
# (Python method, in numpy.ma.masked_array.repeat)
# numpy.ma.masked_array.reshape
# (Python method, in numpy.ma.masked_array.reshape)
# numpy.ma.masked_array.resize
# (Python method, in numpy.ma.masked_array.resize)
# numpy.ma.masked_array.round
# (Python method, in numpy.ma.masked_array.round)
# numpy.ma.masked_array.searchsorted
# (Python method, in numpy.ma.masked_array.searchsorted)
# numpy.ma.masked_array.set_fill_value
# (Python method, in numpy.ma.masked_array.set_fill_value)
# numpy.ma.masked_array.setfield
# (Python method, in numpy.ma.masked_array.setfield)
# numpy.ma.masked_array.setflags
# (Python method, in numpy.ma.masked_array.setflags)
# numpy.ma.masked_array.shape
# (Python property, in numpy.ma.masked_array.shape)
# numpy.ma.masked_array.size
# (Python attribute, in numpy.ma.masked_array.size)
# numpy.ma.masked_array.sort
# (Python method, in numpy.ma.masked_array.sort)
# numpy.ma.masked_array.squeeze
# (Python method, in numpy.ma.masked_array.squeeze)
# numpy.ma.masked_array.std
# (Python method, in numpy.ma.masked_array.std)
# numpy.ma.masked_array.strides
# (Python attribute, in numpy.ma.masked_array.strides)
# numpy.ma.masked_array.sum
# (Python method, in numpy.ma.masked_array.sum)
# numpy.ma.masked_array.swapaxes
# (Python method, in numpy.ma.masked_array.swapaxes)
# numpy.ma.masked_array.T
# (Python property, in numpy.ma.masked_array.T)
# numpy.ma.masked_array.take
# (Python method, in numpy.ma.masked_array.take)
# numpy.ma.masked_array.tobytes
# (Python method, in numpy.ma.masked_array.tobytes)
# numpy.ma.masked_array.tofile
# (Python method, in numpy.ma.masked_array.tofile)
# numpy.ma.masked_array.toflex
# (Python method, in numpy.ma.masked_array.toflex)
# numpy.ma.masked_array.tolist
# (Python method, in numpy.ma.masked_array.tolist)
# numpy.ma.masked_array.torecords
# (Python method, in numpy.ma.masked_array.torecords)
# numpy.ma.masked_array.tostring
# (Python method, in numpy.ma.masked_array.tostring)
# numpy.ma.masked_array.trace
# (Python method, in numpy.ma.masked_array.trace)
# numpy.ma.masked_array.transpose
# (Python method, in numpy.ma.masked_array.transpose)
# numpy.ma.masked_array.var
# (Python method, in numpy.ma.masked_array.var)
# numpy.ma.masked_array.view
# (Python method, in numpy.ma.masked_array.view)
# numpy.ma.MaskedArray.__abs__
# (Python method, in numpy.ma.MaskedArray.__abs__)
# numpy.ma.MaskedArray.__add__
# (Python method, in numpy.ma.MaskedArray.__add__)
# numpy.ma.MaskedArray.__and__
# (Python method, in numpy.ma.MaskedArray.__and__)
# numpy.ma.MaskedArray.__array__
# (Python method, in numpy.ma.MaskedArray.__array__)
# numpy.ma.MaskedArray.__array_priority__
# (Python attribute, in numpy.ma.MaskedArray.__array_priority__)
# numpy.ma.MaskedArray.__array_wrap__
# (Python method, in numpy.ma.MaskedArray.__array_wrap__)
# numpy.ma.MaskedArray.__bool__
# (Python method, in numpy.ma.MaskedArray.__bool__)
# numpy.ma.MaskedArray.__contains__
# (Python method, in numpy.ma.MaskedArray.__contains__)
# numpy.ma.MaskedArray.__copy__
# (Python method, in numpy.ma.MaskedArray.__copy__)
# numpy.ma.MaskedArray.__deepcopy__
# (Python method, in numpy.ma.MaskedArray.__deepcopy__)
# numpy.ma.MaskedArray.__delitem__
# (Python method, in numpy.ma.MaskedArray.__delitem__)
# numpy.ma.MaskedArray.__div__
# (Python method, in numpy.ma.MaskedArray.__div__)
# numpy.ma.MaskedArray.__divmod__
# (Python method, in numpy.ma.MaskedArray.__divmod__)
# numpy.ma.MaskedArray.__eq__
# (Python method, in numpy.ma.MaskedArray.__eq__)
# numpy.ma.MaskedArray.__float__
# (Python method, in numpy.ma.MaskedArray.__float__)
# numpy.ma.MaskedArray.__floordiv__
# (Python method, in numpy.ma.MaskedArray.__floordiv__)
# numpy.ma.MaskedArray.__ge__
# (Python method, in numpy.ma.MaskedArray.__ge__)
# numpy.ma.MaskedArray.__getitem__
# (Python method, in numpy.ma.MaskedArray.__getitem__)
# numpy.ma.MaskedArray.__getstate__
# (Python method, in numpy.ma.MaskedArray.__getstate__)
# numpy.ma.MaskedArray.__gt__
# (Python method, in numpy.ma.MaskedArray.__gt__)
# numpy.ma.MaskedArray.__iadd__
# (Python method, in numpy.ma.MaskedArray.__iadd__)
# numpy.ma.MaskedArray.__iand__
# (Python method, in numpy.ma.MaskedArray.__iand__)
# numpy.ma.MaskedArray.__idiv__
# (Python method, in numpy.ma.MaskedArray.__idiv__)
# numpy.ma.MaskedArray.__ifloordiv__
# (Python method, in numpy.ma.MaskedArray.__ifloordiv__)
# numpy.ma.MaskedArray.__ilshift__
# (Python method, in numpy.ma.MaskedArray.__ilshift__)
# numpy.ma.MaskedArray.__imod__
# (Python method, in numpy.ma.MaskedArray.__imod__)
# numpy.ma.MaskedArray.__imul__
# (Python method, in numpy.ma.MaskedArray.__imul__)
# numpy.ma.MaskedArray.__int__
# (Python method, in numpy.ma.MaskedArray.__int__)
# numpy.ma.MaskedArray.__ior__
# (Python method, in numpy.ma.MaskedArray.__ior__)
# numpy.ma.MaskedArray.__ipow__
# (Python method, in numpy.ma.MaskedArray.__ipow__)
# numpy.ma.MaskedArray.__irshift__
# (Python method, in numpy.ma.MaskedArray.__irshift__)
# numpy.ma.MaskedArray.__isub__
# (Python method, in numpy.ma.MaskedArray.__isub__)
# numpy.ma.MaskedArray.__itruediv__
# (Python method, in numpy.ma.MaskedArray.__itruediv__)
# numpy.ma.MaskedArray.__ixor__
# (Python method, in numpy.ma.MaskedArray.__ixor__)
# numpy.ma.MaskedArray.__le__
# (Python method, in numpy.ma.MaskedArray.__le__)
# numpy.ma.MaskedArray.__len__
# (Python method, in numpy.ma.MaskedArray.__len__)
# numpy.ma.MaskedArray.__lshift__
# (Python method, in numpy.ma.MaskedArray.__lshift__)
# numpy.ma.MaskedArray.__lt__
# (Python method, in numpy.ma.MaskedArray.__lt__)
# numpy.ma.MaskedArray.__mod__
# (Python method, in numpy.ma.MaskedArray.__mod__)
# numpy.ma.MaskedArray.__mul__
# (Python method, in numpy.ma.MaskedArray.__mul__)
# numpy.ma.MaskedArray.__ne__
# (Python method, in numpy.ma.MaskedArray.__ne__)
# numpy.ma.MaskedArray.__new__
# (Python method, in numpy.ma.MaskedArray.__new__)
# numpy.ma.MaskedArray.__or__
# (Python method, in numpy.ma.MaskedArray.__or__)
# numpy.ma.MaskedArray.__pow__
# (Python method, in numpy.ma.MaskedArray.__pow__)
# numpy.ma.MaskedArray.__radd__
# (Python method, in numpy.ma.MaskedArray.__radd__)
# numpy.ma.MaskedArray.__rand__
# (Python method, in numpy.ma.MaskedArray.__rand__)
# numpy.ma.MaskedArray.__rdivmod__
# (Python method, in numpy.ma.MaskedArray.__rdivmod__)
# numpy.ma.MaskedArray.__reduce__
# (Python method, in numpy.ma.MaskedArray.__reduce__)
# numpy.ma.MaskedArray.__repr__
# (Python method, in numpy.ma.MaskedArray.__repr__)
# numpy.ma.MaskedArray.__rfloordiv__
# (Python method, in numpy.ma.MaskedArray.__rfloordiv__)
# numpy.ma.MaskedArray.__rlshift__
# (Python method, in numpy.ma.MaskedArray.__rlshift__)
# numpy.ma.MaskedArray.__rmod__
# (Python method, in numpy.ma.MaskedArray.__rmod__)
# numpy.ma.MaskedArray.__rmul__
# (Python method, in numpy.ma.MaskedArray.__rmul__)
# numpy.ma.MaskedArray.__ror__
# (Python method, in numpy.ma.MaskedArray.__ror__)
# numpy.ma.MaskedArray.__rpow__
# (Python method, in numpy.ma.MaskedArray.__rpow__)
# numpy.ma.MaskedArray.__rrshift__
# (Python method, in numpy.ma.MaskedArray.__rrshift__)
# numpy.ma.MaskedArray.__rshift__
# (Python method, in numpy.ma.MaskedArray.__rshift__)
# numpy.ma.MaskedArray.__rsub__
# (Python method, in numpy.ma.MaskedArray.__rsub__)
# numpy.ma.MaskedArray.__rtruediv__
# (Python method, in numpy.ma.MaskedArray.__rtruediv__)
# numpy.ma.MaskedArray.__rxor__
# (Python method, in numpy.ma.MaskedArray.__rxor__)
# numpy.ma.MaskedArray.__setitem__
# (Python method, in numpy.ma.MaskedArray.__setitem__)
# numpy.ma.MaskedArray.__setstate__
# (Python method, in numpy.ma.MaskedArray.__setstate__)
# numpy.ma.MaskedArray.__str__
# (Python method, in numpy.ma.MaskedArray.__str__)
# numpy.ma.MaskedArray.__sub__
# (Python method, in numpy.ma.MaskedArray.__sub__)
# numpy.ma.MaskedArray.__truediv__
# (Python method, in numpy.ma.MaskedArray.__truediv__)
# numpy.ma.MaskedArray.__xor__
# (Python method, in numpy.ma.MaskedArray.__xor__)
# numpy.ma.MaskedArray.all
# (Python method, in numpy.ma.MaskedArray.all)
# numpy.ma.MaskedArray.anom
# (Python method, in numpy.ma.MaskedArray.anom)
# numpy.ma.MaskedArray.any
# (Python method, in numpy.ma.MaskedArray.any)
# numpy.ma.MaskedArray.argmin
# (Python method, in numpy.ma.MaskedArray.argmin)
# numpy.ma.MaskedArray.argsort
# (Python method, in numpy.ma.MaskedArray.argsort)
# numpy.ma.MaskedArray.astype
# (Python method, in numpy.ma.MaskedArray.astype)
# numpy.ma.MaskedArray.base
# (Python attribute, in numpy.ma.MaskedArray.base)
# numpy.ma.MaskedArray.baseclass
# (Python attribute, in Constants of the
# numpy.ma
# module)
# numpy.ma.MaskedArray.byteswap
# (Python method, in numpy.ma.MaskedArray.byteswap)
# numpy.ma.MaskedArray.choose
# (Python method, in numpy.ma.MaskedArray.choose)
# numpy.ma.MaskedArray.clip
# (Python method, in numpy.ma.MaskedArray.clip)
# numpy.ma.MaskedArray.compress
# (Python method, in numpy.ma.MaskedArray.compress)
# numpy.ma.MaskedArray.compressed
# (Python method, in numpy.ma.MaskedArray.compressed)
# numpy.ma.MaskedArray.conj
# (Python method, in numpy.ma.MaskedArray.conj)
# numpy.ma.MaskedArray.conjugate
# (Python method, in numpy.ma.MaskedArray.conjugate)
# numpy.ma.MaskedArray.copy
# (Python method, in numpy.ma.MaskedArray.copy)
# numpy.ma.MaskedArray.count
# (Python method, in numpy.ma.MaskedArray.count)
# numpy.ma.MaskedArray.ctypes
# (Python attribute, in numpy.ma.MaskedArray.ctypes)
# numpy.ma.MaskedArray.cumprod
# (Python method, in numpy.ma.MaskedArray.cumprod)
# numpy.ma.MaskedArray.cumsum
# (Python method, in numpy.ma.MaskedArray.cumsum)
# numpy.ma.MaskedArray.data
# (Python attribute, in Constants of the
# numpy.ma
# module)
# numpy.ma.MaskedArray.diagonal
# (Python method, in numpy.ma.MaskedArray.diagonal)
# numpy.ma.MaskedArray.dtype
# (Python property, in numpy.ma.MaskedArray.dtype)
# numpy.ma.MaskedArray.dump
# (Python method, in numpy.ma.MaskedArray.dump)
# numpy.ma.MaskedArray.dumps
# (Python method, in numpy.ma.MaskedArray.dumps)
# numpy.ma.MaskedArray.fill
# (Python method, in numpy.ma.MaskedArray.fill)
# numpy.ma.MaskedArray.fill_value
# (Python attribute, in Constants of the
# numpy.ma
# module)
# numpy.ma.MaskedArray.filled
# (Python method, in numpy.ma.MaskedArray.filled)
# numpy.ma.MaskedArray.flags
# (Python attribute, in numpy.ma.MaskedArray.flags)
# numpy.ma.MaskedArray.flat
# (Python property, in numpy.ma.MaskedArray.flat)
# numpy.ma.MaskedArray.flatten
# (Python method, in numpy.ma.MaskedArray.flatten)
# numpy.ma.MaskedArray.get_fill_value
# (Python method, in numpy.ma.MaskedArray.get_fill_value)
# numpy.ma.MaskedArray.ids
# (Python method, in numpy.ma.MaskedArray.ids)
# numpy.ma.MaskedArray.iscontiguous
# (Python method, in numpy.ma.MaskedArray.iscontiguous)
# numpy.ma.MaskedArray.item
# (Python method, in numpy.ma.MaskedArray.item)
# numpy.ma.MaskedArray.itemsize
# (Python attribute, in numpy.ma.MaskedArray.itemsize)
# numpy.ma.MaskedArray.mean
# (Python method, in numpy.ma.MaskedArray.mean)
# numpy.ma.MaskedArray.min
# (Python method, in numpy.ma.MaskedArray.min)
# numpy.ma.MaskedArray.nbytes
# (Python attribute, in numpy.ma.MaskedArray.nbytes)
# numpy.ma.MaskedArray.ndim
# (Python attribute, in numpy.ma.MaskedArray.ndim)
# numpy.ma.MaskedArray.nonzero
# (Python method, in numpy.ma.MaskedArray.nonzero)
# numpy.ma.MaskedArray.prod
# (Python method, in numpy.ma.MaskedArray.prod)
# numpy.ma.MaskedArray.product
# (Python method, in numpy.ma.MaskedArray.product)
# numpy.ma.MaskedArray.ptp
# (Python method, in numpy.ma.MaskedArray.ptp)
# numpy.ma.MaskedArray.put
# (Python method, in numpy.ma.MaskedArray.put)
# numpy.ma.MaskedArray.ravel
# (Python method, in numpy.ma.MaskedArray.ravel)
# numpy.ma.MaskedArray.real
# (Python property, in numpy.ma.MaskedArray.real)
# numpy.ma.MaskedArray.repeat
# (Python method, in numpy.ma.MaskedArray.repeat)
# numpy.ma.MaskedArray.reshape
# (Python method, in numpy.ma.MaskedArray.reshape)
# numpy.ma.MaskedArray.resize
# (Python method, in numpy.ma.MaskedArray.resize)
# numpy.ma.MaskedArray.round
# (Python method, in numpy.ma.MaskedArray.round)
# numpy.ma.MaskedArray.searchsorted
# (Python method, in numpy.ma.MaskedArray.searchsorted)
# numpy.ma.MaskedArray.set_fill_value
# (Python method, in numpy.ma.MaskedArray.set_fill_value)
# numpy.ma.MaskedArray.shape
# (Python property, in numpy.ma.MaskedArray.shape)
# numpy.ma.MaskedArray.size
# (Python attribute, in numpy.ma.MaskedArray.size)
# numpy.ma.MaskedArray.sort
# (Python method, in numpy.ma.MaskedArray.sort)
# numpy.ma.MaskedArray.squeeze
# (Python method, in numpy.ma.MaskedArray.squeeze)
# numpy.ma.MaskedArray.std
# (Python method, in numpy.ma.MaskedArray.std)
# numpy.ma.MaskedArray.strides
# (Python attribute, in numpy.ma.MaskedArray.strides)
# numpy.ma.MaskedArray.sum
# (Python method, in numpy.ma.MaskedArray.sum)
# numpy.ma.MaskedArray.swapaxes
# (Python method, in numpy.ma.MaskedArray.swapaxes)
# numpy.ma.MaskedArray.T
# (Python property, in numpy.ma.MaskedArray.T)
# numpy.ma.MaskedArray.take
# (Python method, in numpy.ma.MaskedArray.take)
# numpy.ma.MaskedArray.tobytes
# (Python method, in numpy.ma.MaskedArray.tobytes)
# numpy.ma.MaskedArray.tofile
# (Python method, in numpy.ma.MaskedArray.tofile)
# numpy.ma.MaskedArray.toflex
# (Python method, in numpy.ma.MaskedArray.toflex)
# numpy.ma.MaskedArray.tolist
# (Python method, in numpy.ma.MaskedArray.tolist)
# numpy.ma.MaskedArray.torecords
# (Python method, in numpy.ma.MaskedArray.torecords)
# numpy.ma.MaskedArray.tostring
# (Python method, in numpy.ma.MaskedArray.tostring)
# numpy.ma.MaskedArray.trace
# (Python method, in numpy.ma.MaskedArray.trace)
# numpy.ma.MaskedArray.transpose
# (Python method, in numpy.ma.MaskedArray.transpose)
# numpy.ma.MaskedArray.var
# (Python method, in numpy.ma.MaskedArray.var)
# numpy.ma.MaskedArray.view
# (Python method, in numpy.ma.MaskedArray.view)
# numpy.ma.MaskType.all
# (Python method, in numpy.ma.MaskType.all)
# numpy.ma.MaskType.any
# (Python method, in numpy.ma.MaskType.any)
# numpy.ma.MaskType.argmin
# (Python method, in numpy.ma.MaskType.argmin)
# numpy.ma.MaskType.argsort
# (Python method, in numpy.ma.MaskType.argsort)
# numpy.ma.MaskType.astype
# (Python method, in numpy.ma.MaskType.astype)
# numpy.ma.MaskType.base
# (Python attribute, in numpy.ma.MaskType.base)
# numpy.ma.MaskType.byteswap
# (Python method, in numpy.ma.MaskType.byteswap)
# numpy.ma.MaskType.choose
# (Python method, in numpy.ma.MaskType.choose)
# numpy.ma.MaskType.clip
# (Python method, in numpy.ma.MaskType.clip)
# numpy.ma.MaskType.compress
# (Python method, in numpy.ma.MaskType.compress)
# numpy.ma.MaskType.conj
# (Python method, in numpy.ma.MaskType.conj)
# numpy.ma.MaskType.conjugate
# (Python method, in numpy.ma.MaskType.conjugate)
# numpy.ma.MaskType.copy
# (Python method, in numpy.ma.MaskType.copy)
# numpy.ma.MaskType.cumprod
# (Python method, in numpy.ma.MaskType.cumprod)
# numpy.ma.MaskType.cumsum
# (Python method, in numpy.ma.MaskType.cumsum)
# numpy.ma.MaskType.data
# (Python attribute, in numpy.ma.MaskType.data)
# numpy.ma.MaskType.diagonal
# (Python method, in numpy.ma.MaskType.diagonal)
# numpy.ma.MaskType.dtype
# (Python attribute, in numpy.ma.MaskType.dtype)
# numpy.ma.MaskType.dump
# (Python method, in numpy.ma.MaskType.dump)
# numpy.ma.MaskType.dumps
# (Python method, in numpy.ma.MaskType.dumps)
# numpy.ma.MaskType.fill
# (Python method, in numpy.ma.MaskType.fill)
# numpy.ma.MaskType.flags
# (Python attribute, in numpy.ma.MaskType.flags)
# numpy.ma.MaskType.flat
# (Python attribute, in numpy.ma.MaskType.flat)
# numpy.ma.MaskType.flatten
# (Python method, in numpy.ma.MaskType.flatten)
# numpy.ma.MaskType.getfield
# (Python method, in numpy.ma.MaskType.getfield)
# numpy.ma.MaskType.item
# (Python method, in numpy.ma.MaskType.item)
# numpy.ma.MaskType.itemset
# (Python method, in numpy.ma.MaskType.itemset)
# numpy.ma.MaskType.itemsize
# (Python attribute, in numpy.ma.MaskType.itemsize)
# numpy.ma.MaskType.mean
# (Python method, in numpy.ma.MaskType.mean)
# numpy.ma.MaskType.min
# (Python method, in numpy.ma.MaskType.min)
# numpy.ma.MaskType.nbytes
# (Python attribute, in numpy.ma.MaskType.nbytes)
# numpy.ma.MaskType.ndim
# (Python attribute, in numpy.ma.MaskType.ndim)
# numpy.ma.MaskType.newbyteorder
# (Python method, in numpy.ma.MaskType.newbyteorder)
# numpy.ma.MaskType.nonzero
# (Python method, in numpy.ma.MaskType.nonzero)
# numpy.ma.MaskType.prod
# (Python method, in numpy.ma.MaskType.prod)
# numpy.ma.MaskType.ptp
# (Python method, in numpy.ma.MaskType.ptp)
# numpy.ma.MaskType.put
# (Python method, in numpy.ma.MaskType.put)
# numpy.ma.MaskType.ravel
# (Python method, in numpy.ma.MaskType.ravel)
# numpy.ma.MaskType.real
# (Python attribute, in numpy.ma.MaskType.real)
# numpy.ma.MaskType.repeat
# (Python method, in numpy.ma.MaskType.repeat)
# numpy.ma.MaskType.reshape
# (Python method, in numpy.ma.MaskType.reshape)
# numpy.ma.MaskType.resize
# (Python method, in numpy.ma.MaskType.resize)
# numpy.ma.MaskType.round
# (Python method, in numpy.ma.MaskType.round)
# numpy.ma.MaskType.searchsorted
# (Python method, in numpy.ma.MaskType.searchsorted)
# numpy.ma.MaskType.setfield
# (Python method, in numpy.ma.MaskType.setfield)
# numpy.ma.MaskType.setflags
# (Python method, in numpy.ma.MaskType.setflags)
# numpy.ma.MaskType.shape
# (Python attribute, in numpy.ma.MaskType.shape)
# numpy.ma.MaskType.size
# (Python attribute, in numpy.ma.MaskType.size)
# numpy.ma.MaskType.sort
# (Python method, in numpy.ma.MaskType.sort)
# numpy.ma.MaskType.squeeze
# (Python method, in numpy.ma.MaskType.squeeze)
# numpy.ma.MaskType.std
# (Python method, in numpy.ma.MaskType.std)
# numpy.ma.MaskType.strides
# (Python attribute, in numpy.ma.MaskType.strides)
# numpy.ma.MaskType.sum
# (Python method, in numpy.ma.MaskType.sum)
# numpy.ma.MaskType.swapaxes
# (Python method, in numpy.ma.MaskType.swapaxes)
# numpy.ma.MaskType.T
# (Python attribute, in numpy.ma.MaskType.T)
# numpy.ma.MaskType.take
# (Python method, in numpy.ma.MaskType.take)
# numpy.ma.MaskType.tobytes
# (Python method, in numpy.ma.MaskType.tobytes)
# numpy.ma.MaskType.tofile
# (Python method, in numpy.ma.MaskType.tofile)
# numpy.ma.MaskType.tolist
# (Python method, in numpy.ma.MaskType.tolist)
# numpy.ma.MaskType.tostring
# (Python method, in numpy.ma.MaskType.tostring)
# numpy.ma.MaskType.trace
# (Python method, in numpy.ma.MaskType.trace)
# numpy.ma.MaskType.transpose
# (Python method, in numpy.ma.MaskType.transpose)
# numpy.ma.MaskType.var
# (Python method, in numpy.ma.MaskType.var)
# numpy.ma.MaskType.view
# (Python method, in numpy.ma.MaskType.view)
# numpy.ma.mean
# (Python data, in numpy.ma.mean)
# numpy.ma.median
# (Python function, in numpy.ma.median)
# numpy.ma.min
# (Python function, in numpy.ma.min)
# numpy.ma.minimum_fill_value
# (Python function, in numpy.ma.minimum_fill_value)
# numpy.ma.mr_
# (Python data, in numpy.ma.mr_)
# numpy.ma.nonzero
# (Python data, in numpy.ma.nonzero)
# numpy.ma.ones
# (Python data, in numpy.ma.ones)
# numpy.ma.outer
# (Python function, in numpy.ma.outer)
# numpy.ma.outerproduct
# (Python function, in numpy.ma.outerproduct)
# numpy.ma.polyfit
# (Python function, in numpy.ma.polyfit)
# numpy.ma.power
# (Python function, in numpy.ma.power)
# numpy.ma.prod
# (Python data, in numpy.ma.prod)
# numpy.ma.ptp
# (Python function, in numpy.ma.ptp)
# numpy.ma.ravel
# (Python data, in numpy.ma.ravel)
# numpy.ma.reshape
# (Python function, in numpy.ma.reshape)
# numpy.ma.resize
# (Python function, in numpy.ma.resize)
# numpy.ma.round
# (Python function, in numpy.ma.round)
# numpy.ma.row_stack
# (Python data, in numpy.ma.row_stack)
# numpy.ma.set_fill_value
# (Python function, in numpy.ma.set_fill_value)
# numpy.ma.shape
# (Python function, in numpy.ma.shape)
# numpy.ma.size
# (Python function, in numpy.ma.size)
# numpy.ma.sort
# (Python function, in numpy.ma.sort)
# numpy.ma.squeeze
# (Python function, in numpy.ma.squeeze)
# numpy.ma.stack
# (Python data, in numpy.ma.stack)
# numpy.ma.std
# (Python data, in numpy.ma.std)
# numpy.ma.sum
# (Python data, in numpy.ma.sum)
# numpy.ma.swapaxes
# (Python data, in numpy.ma.swapaxes)
# numpy.ma.trace
# (Python data, in numpy.ma.trace)
# numpy.ma.transpose
# (Python function, in numpy.ma.transpose)
# numpy.ma.vander
# (Python function, in numpy.ma.vander)
# numpy.ma.var
# (Python data, in numpy.ma.var)
# numpy.ma.vstack
# (Python data, in numpy.ma.vstack)
# numpy.ma.where
# (Python function, in numpy.ma.where)
# numpy.ma.zeros
# (Python data, in numpy.ma.zeros)
# numpy.matlib.empty
# (Python function, in numpy.matlib.empty)
# numpy.matlib.eye
# (Python function, in numpy.matlib.eye)
# numpy.matlib.identity
# (Python function, in numpy.matlib.identity)
# numpy.matlib.ones
# (Python function, in numpy.matlib.ones)
# numpy.matlib.rand
# (Python function, in numpy.matlib.rand)
# numpy.matlib.randn
# (Python function, in numpy.matlib.randn)
# numpy.matlib.zeros
# (Python function, in numpy.matlib.zeros)
# numpy.matrix.A
# (Python property, in numpy.matrix.A)
# numpy.matrix.A1
# (Python property, in numpy.matrix.A1)
# numpy.matrix.all
# (Python method, in numpy.matrix.all)
# numpy.matrix.any
# (Python method, in numpy.matrix.any)
# numpy.matrix.argmin
# (Python method, in numpy.matrix.argmin)
# numpy.matrix.argpartition
# (Python method, in numpy.matrix.argpartition)
# numpy.matrix.argsort
# (Python method, in numpy.matrix.argsort)
# numpy.matrix.astype
# (Python method, in numpy.matrix.astype)
# numpy.matrix.base
# (Python attribute, in numpy.matrix.base)
# numpy.matrix.byteswap
# (Python method, in numpy.matrix.byteswap)
# numpy.matrix.choose
# (Python method, in numpy.matrix.choose)
# numpy.matrix.clip
# (Python method, in numpy.matrix.clip)
# numpy.matrix.compress
# (Python method, in numpy.matrix.compress)
# numpy.matrix.conj
# (Python method, in numpy.matrix.conj)
# numpy.matrix.conjugate
# (Python method, in numpy.matrix.conjugate)
# numpy.matrix.copy
# (Python method, in numpy.matrix.copy)
# numpy.matrix.ctypes
# (Python attribute, in numpy.matrix.ctypes)
# numpy.matrix.cumprod
# (Python method, in numpy.matrix.cumprod)
# numpy.matrix.cumsum
# (Python method, in numpy.matrix.cumsum)
# numpy.matrix.data
# (Python attribute, in numpy.matrix.data)
# numpy.matrix.diagonal
# (Python method, in numpy.matrix.diagonal)
# numpy.matrix.dot
# (Python method, in numpy.matrix.dot)
# numpy.matrix.dtype
# (Python attribute, in numpy.matrix.dtype)
# numpy.matrix.dump
# (Python method, in numpy.matrix.dump)
# numpy.matrix.dumps
# (Python method, in numpy.matrix.dumps)
# numpy.matrix.fill
# (Python method, in numpy.matrix.fill)
# numpy.matrix.flags
# (Python attribute, in numpy.matrix.flags)
# numpy.matrix.flat
# (Python attribute, in numpy.matrix.flat)
# numpy.matrix.flatten
# (Python method, in numpy.matrix.flatten)
# numpy.matrix.getA
# (Python method, in numpy.matrix.getA)
# numpy.matrix.getA1
# (Python method, in numpy.matrix.getA1)
# numpy.matrix.getfield
# (Python method, in numpy.matrix.getfield)
# numpy.matrix.getH
# (Python method, in numpy.matrix.getH)
# numpy.matrix.getI
# (Python method, in numpy.matrix.getI)
# numpy.matrix.getT
# (Python method, in numpy.matrix.getT)
# numpy.matrix.H
# (Python property, in numpy.matrix.H)
# numpy.matrix.I
# (Python property, in numpy.matrix.I)
# numpy.matrix.item
# (Python method, in numpy.matrix.item)
# numpy.matrix.itemset
# (Python method, in numpy.matrix.itemset)
# numpy.matrix.itemsize
# (Python attribute, in numpy.matrix.itemsize)
# numpy.matrix.mean
# (Python method, in numpy.matrix.mean)
# numpy.matrix.min
# (Python method, in numpy.matrix.min)
# numpy.matrix.nbytes
# (Python attribute, in numpy.matrix.nbytes)
# numpy.matrix.ndim
# (Python attribute, in numpy.matrix.ndim)
# numpy.matrix.newbyteorder
# (Python method, in numpy.matrix.newbyteorder)
# numpy.matrix.nonzero
# (Python method, in numpy.matrix.nonzero)
# numpy.matrix.partition
# (Python method, in numpy.matrix.partition)
# numpy.matrix.prod
# (Python method, in numpy.matrix.prod)
# numpy.matrix.ptp
# (Python method, in numpy.matrix.ptp)
# numpy.matrix.put
# (Python method, in numpy.matrix.put)
# numpy.matrix.ravel
# (Python method, in numpy.matrix.ravel)
# numpy.matrix.real
# (Python attribute, in numpy.matrix.real)
# numpy.matrix.repeat
# (Python method, in numpy.matrix.repeat)
# numpy.matrix.reshape
# (Python method, in numpy.matrix.reshape)
# numpy.matrix.resize
# (Python method, in numpy.matrix.resize)
# numpy.matrix.round
# (Python method, in numpy.matrix.round)
# numpy.matrix.searchsorted
# (Python method, in numpy.matrix.searchsorted)
# numpy.matrix.setfield
# (Python method, in numpy.matrix.setfield)
# numpy.matrix.setflags
# (Python method, in numpy.matrix.setflags)
# numpy.matrix.shape
# (Python attribute, in numpy.matrix.shape)
# numpy.matrix.size
# (Python attribute, in numpy.matrix.size)
# numpy.matrix.sort
# (Python method, in numpy.matrix.sort)
# numpy.matrix.squeeze
# (Python method, in numpy.matrix.squeeze)
# numpy.matrix.std
# (Python method, in numpy.matrix.std)
# numpy.matrix.strides
# (Python attribute, in numpy.matrix.strides)
# numpy.matrix.sum
# (Python method, in numpy.matrix.sum)
# numpy.matrix.swapaxes
# (Python method, in numpy.matrix.swapaxes)
# numpy.matrix.T
# (Python property, in numpy.matrix.T)
# numpy.matrix.take
# (Python method, in numpy.matrix.take)
# numpy.matrix.tobytes
# (Python method, in numpy.matrix.tobytes)
# numpy.matrix.tofile
# (Python method, in numpy.matrix.tofile)
# numpy.matrix.tolist
# (Python method, in numpy.matrix.tolist)
# numpy.matrix.tostring
# (Python method, in numpy.matrix.tostring)
# numpy.matrix.trace
# (Python method, in numpy.matrix.trace)
# numpy.matrix.transpose
# (Python method, in numpy.matrix.transpose)
# numpy.matrix.var
# (Python method, in numpy.matrix.var)
# numpy.matrix.view
# (Python method, in numpy.matrix.view)
# numpy.memmap.all
# (Python method, in numpy.memmap.all)
# numpy.memmap.any
# (Python method, in numpy.memmap.any)
# numpy.memmap.argmin
# (Python method, in numpy.memmap.argmin)
# numpy.memmap.argpartition
# (Python method, in numpy.memmap.argpartition)
# numpy.memmap.argsort
# (Python method, in numpy.memmap.argsort)
# numpy.memmap.astype
# (Python method, in numpy.memmap.astype)
# numpy.memmap.base
# (Python attribute, in numpy.memmap.base)
# numpy.memmap.byteswap
# (Python method, in numpy.memmap.byteswap)
# numpy.memmap.choose
# (Python method, in numpy.memmap.choose)
# numpy.memmap.clip
# (Python method, in numpy.memmap.clip)
# numpy.memmap.compress
# (Python method, in numpy.memmap.compress)
# numpy.memmap.conj
# (Python method, in numpy.memmap.conj)
# numpy.memmap.conjugate
# (Python method, in numpy.memmap.conjugate)
# numpy.memmap.copy
# (Python method, in numpy.memmap.copy)
# numpy.memmap.ctypes
# (Python attribute, in numpy.memmap.ctypes)
# numpy.memmap.cumprod
# (Python method, in numpy.memmap.cumprod)
# numpy.memmap.cumsum
# (Python method, in numpy.memmap.cumsum)
# numpy.memmap.data
# (Python attribute, in numpy.memmap.data)
# numpy.memmap.diagonal
# (Python method, in numpy.memmap.diagonal)
# numpy.memmap.dot
# (Python method, in numpy.memmap.dot)
# numpy.memmap.dtype
# (Python attribute, in numpy.memmap.dtype)
# numpy.memmap.dump
# (Python method, in numpy.memmap.dump)
# numpy.memmap.dumps
# (Python method, in numpy.memmap.dumps)
# numpy.memmap.fill
# (Python method, in numpy.memmap.fill)
# numpy.memmap.flags
# (Python attribute, in numpy.memmap.flags)
# numpy.memmap.flat
# (Python attribute, in numpy.memmap.flat)
# numpy.memmap.flatten
# (Python method, in numpy.memmap.flatten)
# numpy.memmap.flush
# (Python method, in numpy.memmap.flush)
# numpy.memmap.getfield
# (Python method, in numpy.memmap.getfield)
# numpy.memmap.item
# (Python method, in numpy.memmap.item)
# numpy.memmap.itemset
# (Python method, in numpy.memmap.itemset)
# numpy.memmap.itemsize
# (Python attribute, in numpy.memmap.itemsize)
# numpy.memmap.mean
# (Python method, in numpy.memmap.mean)
# numpy.memmap.min
# (Python method, in numpy.memmap.min)
# numpy.memmap.nbytes
# (Python attribute, in numpy.memmap.nbytes)
# numpy.memmap.ndim
# (Python attribute, in numpy.memmap.ndim)
# numpy.memmap.newbyteorder
# (Python method, in numpy.memmap.newbyteorder)
# numpy.memmap.nonzero
# (Python method, in numpy.memmap.nonzero)
# numpy.memmap.partition
# (Python method, in numpy.memmap.partition)
# numpy.memmap.prod
# (Python method, in numpy.memmap.prod)
# numpy.memmap.ptp
# (Python method, in numpy.memmap.ptp)
# numpy.memmap.put
# (Python method, in numpy.memmap.put)
# numpy.memmap.ravel
# (Python method, in numpy.memmap.ravel)
# numpy.memmap.real
# (Python attribute, in numpy.memmap.real)
# numpy.memmap.repeat
# (Python method, in numpy.memmap.repeat)
# numpy.memmap.reshape
# (Python method, in numpy.memmap.reshape)
# numpy.memmap.resize
# (Python method, in numpy.memmap.resize)
# numpy.memmap.round
# (Python method, in numpy.memmap.round)
# numpy.memmap.searchsorted
# (Python method, in numpy.memmap.searchsorted)
# numpy.memmap.setfield
# (Python method, in numpy.memmap.setfield)
# numpy.memmap.setflags
# (Python method, in numpy.memmap.setflags)
# numpy.memmap.shape
# (Python attribute, in numpy.memmap.shape)
# numpy.memmap.size
# (Python attribute, in numpy.memmap.size)
# numpy.memmap.sort
# (Python method, in numpy.memmap.sort)
# numpy.memmap.squeeze
# (Python method, in numpy.memmap.squeeze)
# numpy.memmap.std
# (Python method, in numpy.memmap.std)
# numpy.memmap.strides
# (Python attribute, in numpy.memmap.strides)
# numpy.memmap.sum
# (Python method, in numpy.memmap.sum)
# numpy.memmap.swapaxes
# (Python method, in numpy.memmap.swapaxes)
# numpy.memmap.T
# (Python attribute, in numpy.memmap.T)
# numpy.memmap.take
# (Python method, in numpy.memmap.take)
# numpy.memmap.tobytes
# (Python method, in numpy.memmap.tobytes)
# numpy.memmap.tofile
# (Python method, in numpy.memmap.tofile)
# numpy.memmap.tolist
# (Python method, in numpy.memmap.tolist)
# numpy.memmap.tostring
# (Python method, in numpy.memmap.tostring)
# numpy.memmap.trace
# (Python method, in numpy.memmap.trace)
# numpy.memmap.transpose
# (Python method, in numpy.memmap.transpose)
# numpy.memmap.var
# (Python method, in numpy.memmap.var)
# numpy.memmap.view
# (Python method, in numpy.memmap.view)
# numpy.random.Generator.zipf
# numpy.random.RandomState.zipf
# numpy.random.zipf
# numpy.testing.suppress_warnings
# PyArray_ArgMax.axis
# (C function parameter, in Array API)
# PyArray_ArgMax.out
# (C function parameter, in Array API)
# PyArray_ArgMax.self
# (C function parameter, in Array API)
# PyArray_CheckFromAny.context
# (C function parameter, in Array API)
# PyArray_CheckFromAny.dtype
# (C function parameter, in Array API)
# PyArray_CheckFromAny.min_depth
# (C function parameter, in Array API)
# PyArray_CheckFromAny.op
# (C function parameter, in Array API)
# PyArray_CheckFromAny.requirements
# (C function parameter, in Array API)
# PyArray_ContiguousFromAny.min_depth
# (C function parameter, in Array API)
# PyArray_ContiguousFromAny.op
# (C function parameter, in Array API)
# PyArray_ContiguousFromAny.typenum
# (C function parameter, in Array API)
# PyArray_FromAny.context
# (C function parameter, in Array API)
# PyArray_FromAny.dtype
# (C function parameter, in Array API)
# PyArray_FROMANY.min
# (C function parameter, in Array API)
# PyArray_FromAny.min_depth
# (C function parameter, in Array API)
# PyArray_FromAny.NPY_ARRAY_ALIGNED
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_BEHAVED
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_C_CONTIGUOUS
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_CARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_CARRAY_RO
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_DEFAULT
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_ENSUREARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_ENSURECOPY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_F_CONTIGUOUS
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_FARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_FARRAY_RO
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_FORCECAST
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_IN_ARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_IN_FARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_INOUT_ARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_INOUT_FARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_OUT_ARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_OUT_FARRAY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_UPDATEIFCOPY
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_WRITEABLE
# (C macro, in Array API)
# PyArray_FromAny.NPY_ARRAY_WRITEBACKIFCOPY
# (C macro, in Array API)
# PyArray_FromAny.NPY_OUT_ARRAY
# (C macro, in Array API)
# PyArray_FROMANY.obj
# (C function parameter, in Array API)
# PyArray_FromAny.op
# (C function parameter, in Array API)
# PyArray_FromAny.requirements
# (C function parameter, in Array API)
# PyArray_FROMANY.requirements
# (C function parameter, in Array API)
# PyArray_FROMANY.typenum
# (C function parameter, in Array API)
# PyArray_FromArray.newtype
# (C function parameter, in Array API)
# PyArray_FromArray.op
# (C function parameter, in Array API)
# PyArray_FromArray.requirements
# (C function parameter, in Array API)
# PyArray_FromArrayAttr.context
# (C function parameter, in Array API)
# PyArray_FromArrayAttr.dtype
# (C function parameter, in Array API)
# PyArray_FromArrayAttr.op
# (C function parameter, in Array API)
# PyArray_malloc.nbytes
# (C function parameter, in Array API)
# PyArray_MatrixProduct.obj
# (C function parameter, in Array API)
# PyArray_MatrixProduct.obj1
# (C function parameter, in Array API)
# PyArray_MatrixProduct2.obj
# (C function parameter, in Array API)
# PyArray_MatrixProduct2.obj1
# (C function parameter, in Array API)
# PyArray_MatrixProduct2.out
# (C function parameter, in Array API)
# PyArray_Max.axis
# (C function parameter, in Array API)
# PyArray_Max.out
# (C function parameter, in Array API)
# PyArray_Max.self
# (C function parameter, in Array API)
# PyArray_PutMask.self
# (C function parameter, in Array API)
# PyArray_PutMask.values
# (C function parameter, in Array API)
# PyArray_RemoveSmallest.mit
# (C function parameter, in Array API)
# random_gamma.bitgen_state
# (C function parameter, in C API for random)
# random_gamma.scale
# (C function parameter, in C API for random)
# random_gamma.shape
# (C function parameter, in C API for random)
# random_gamma_f.bitgen_state
# (C function parameter, in C API for random)
# random_gamma_f.scale
# (C function parameter, in C API for random)
# random_gamma_f.shape
# (C function parameter, in C API for random)
# random_lognormal.bitgen_state
# (C function parameter, in C API for random)
# random_lognormal.mean
# (C function parameter, in C API for random)
# random_multivariate_hypergeometric_marginals.bitgen_state
# (C function parameter, in C API for random)
# random_multivariate_hypergeometric_marginals.colors
# (C function parameter, in C API for random)
# random_multivariate_hypergeometric_marginals.nsample
# (C function parameter, in C API for random)
# random_multivariate_hypergeometric_marginals.num_colors
# (C function parameter, in C API for random)
# random_multivariate_hypergeometric_marginals.num_variates
# (C function parameter, in C API for random)
# random_multivariate_hypergeometric_marginals.total
# (C function parameter, in C API for random)
# random_multivariate_hypergeometric_marginals.variates
# (C function parameter, in C API for random)
# random_normal.bitgen_state
# (C function parameter, in C API for random)
# random_normal.loc
# (C function parameter, in C API for random)
# random_normal.scale
# (C function parameter, in C API for random)
# random_standard_gamma.bitgen_state
# (C function parameter, in C API for random)
# random_standard_gamma.shape
# (C function parameter, in C API for random)
# random_standard_gamma_f.bitgen_state
# (C function parameter, in C API for random)
# random_standard_gamma_f.shape
# (C function parameter, in C API for random)
# random_standard_normal.bitgen_state
# (C function parameter, in C API for random)
# random_standard_normal_f.bitgen_state
# (C function parameter, in C API for random)
# random_standard_normal_fill.bitgen_state
# (C function parameter, in C API for random)
# random_standard_normal_fill.count
# (C function parameter, in C API for random)
# random_standard_normal_fill.out
# (C function parameter, in C API for random)
# random_standard_normal_fill_f.bitgen_state
# (C function parameter, in C API for random)
# random_standard_normal_fill_f.count
# (C function parameter, in C API for random)
# random_standard_normal_fill_f.out
# (C function parameter, in C API for random)
# Release Notes
# Structured arrays
# Tutorial: Masked Arrays
# © Copyright 2008-2021, The NumPy community.
# Last updated on Jun 22, 2021.
# Created using
# Sphinx
# 4.0.1.
# ```
